# %%
import ibis
import warnings; 
warnings.filterwarnings('ignore')

con = ibis.timeplus.connect(
           host="timeplus",
           port=8463,
           password="timeplus@t+",
           user="proton",
       )

r = con.sql("select * from online_payments")
result = r.execute()
for results in result:
    print(results)
# Out:
# ('57fdd69e-1edb-49ed-b0a7-571809195e37', 'TRANSFER', 883.36, 'C818504451728', 1005.97, 122.61, 'C177672879990', 1003.46, 1886.82, datetime.datetime(2024, 11, 8, 18, 45, 42, 46000, tzinfo=<UTC>))
# ('dc008622-091d-48d7-870d-813198ceb882', 'PAYMENT', 383.61, 'C275215291941', 1001.54, 617.93, 'M496068738740', 0.0, 0.0, datetime.datetime(2024, 11, 8, 18, 45, 42, 46000, tzinfo=<UTC>))
# ('b6b1c5cc-4797-4e95-a263-b8a80fb729d7', 'PAYMENT', 4.02, 'C923181827551', 1018.77, 1014.75, 'M952468981262', 0.0, 0.0, datetime.datetime(2024, 11, 8, 18, 45, 42, 46000, tzinfo=<UTC>))
# ('4a0ef85b-0892-4382-84da-996116695826', 'TRANSFER', 58.77, 'C723588336144', 1003.22, 944.45, 'C719244404903', 817.3, 876.07, datetime.datetime(2024, 11, 8, 18, 45, 42, 46000, tzinfo=<UTC>))
# ('2c9fa34a-fe9d-4cf5-a5d9-204fcbc327f7', 'PAYMENT', 126.7, 'C552938657546', 1004.66, 877.96, 'M573354938291', 0.0, 0.0, datetime.datetime(2024, 11, 8, 18, 45, 42, 46000, tzinfo=<UTC>))
# ...
